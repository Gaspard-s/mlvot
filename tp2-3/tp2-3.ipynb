# %%
import numpy as np
import pandas as pd
from scipy.optimize import linear_sum_assignment
import cv2
import os

# %% [markdown]
# # TP2

# %%
def load_detections(fichier_det):
    # Noms des colonnes selon le format MOT Challenge
    noms_colonnes = ['frame', 'id', 'bb_left', 'bb_top', 'bb_width', 'bb_height', 'conf', 'x', 'y', 'z']
    
    # Charger le fichier en utilisant pandas
    detections = pd.read_csv(fichier_det, header=None, names=noms_colonnes, sep=' ')
    
    return detections

# Charger les détections depuis les différents modèles
det_yolov5s = load_detections('ADL-Rundle-6/det/Yolov5s/det.txt')
det_yolov5l = load_detections('ADL-Rundle-6/det/Yolov5l/det.txt')

# Afficher les premières lignes pour vérification
print("Détections YOLOv5s:")
print(det_yolov5s.head())
print("\nDétections YOLOv5l:")
print(det_yolov5l.head())
# Out:
# Détections YOLOv5s:
#    frame  id  bb_left  bb_top  bb_width  bb_height      conf  x  y  z
# 0      1  -1     1695     386       136        342  0.760947 -1 -1 -1
# 1      1  -1      255     459       103        246  0.676300 -1 -1 -1
# 2      1  -1     1885     380        34        202  0.628092 -1 -1 -1
# 3      1  -1        2     306        81        614  0.575901 -1 -1 -1
# 4      1  -1     1284     463        74        195  0.575504 -1 -1 -1
#
# Détections YOLOv5l:
#    frame  id  bb_left  bb_top  bb_width  bb_height      conf  x  y  z
# 0      1  -1     1700     391       156        337  0.914550 -1 -1 -1
# 1      1  -1      250     456       107        248  0.883148 -1 -1 -1
# 2      1  -1     1255     539        60        118  0.826354 -1 -1 -1
# 3      1  -1     1288     459        73        199  0.745969 -1 -1 -1
# 4      1  -1      120     504        93        239  0.740778 -1 -1 -1

# %%
def calculate_iou(box1, box2):
    b1_x1, b1_y1 = box1[0], box1[1]
    b1_x2, b1_y2 = box1[0] + box1[2], box1[1] + box1[3]
    b2_x1, b2_y1 = box2[0], box2[1] 
    b2_x2, b2_y2 = box2[0] + box2[2], box2[1] + box2[3]

    inter_x1 = max(b1_x1, b2_x1)
    inter_y1 = max(b1_y1, b2_y1)
    inter_x2 = min(b1_x2, b2_x2)
    inter_y2 = min(b1_y2, b2_y2)

    inter_area = max(0, inter_x2 - inter_x1) * max(0, inter_y2 - inter_y1)
    
    b1_area = (b1_x2 - b1_x1) * (b1_y2 - b1_y1)
    b2_area = (b2_x2 - b2_x1) * (b2_y2 - b2_y1)
    
    union_area = b1_area + b2_area - inter_area
    
    return inter_area / union_area if union_area > 0 else 0

# %%
def calculate_similarity_matrix(tracked_boxes, new_detections):
    # Vérifier si les entrées sont des DataFrames ou des listes
    if hasattr(tracked_boxes, 'iloc'):
        tracked_bboxes = tracked_boxes.iloc[:, 2:6].values.tolist()
    else:
        tracked_bboxes = tracked_boxes
        
    if hasattr(new_detections, 'iloc'):
        detection_bboxes = new_detections.iloc[:, 2:6].values.tolist()
    else:
        detection_bboxes = new_detections
    
    # Initialiser la matrice de similarité
    n_tracked = len(tracked_bboxes)
    n_detections = len(detection_bboxes)
    similarity_matrix = np.zeros((n_tracked, n_detections))
    
    # Calculer l'IoU pour chaque paire de boîtes
 250, 677], [1645, 379, 169, 372], [288, 454, 118, 250], [1859, 316, 61, 440], [1300, 537, 48, 124], [1807, 446, 58, 175], [1328, 462, 68, 201], [0, 241, 269, 674], [1639, 381, 172, 373], [308, 454, 100, 249], [1854, 319, 66, 441], [1806, 445, 60, 176], [1301, 539, 45, 121], [1332, 464, 69, 197], [0, 241, 292, 671], [306, 452, 101, 251], [1848, 320, 71, 441], [1633, 382, 164, 376], [1807, 445, 58, 175], [1304, 538, 43, 123], [1331, 468, 64, 195], [0, 239, 323, 670], [307, 453, 100, 250], [1838, 321, 82, 442], [1635, 384, 158, 374], [1307, 538, 41, 123], [1813, 443, 52, 174], [1332, 468, 65, 197], [2, 236, 328, 665], [1629, 384, 160, 376], [1838, 322, 82, 443], [311, 455, 96, 248], [1308, 538, 41,  ...

# %%
cost_matrix = 1 - similarity_matrix
tracked_indices, detection_indices = linear_sum_assignment(cost_matrix)

print("Assignations optimales:")
for track_idx, det_idx in zip(tracked_indices, detection_indices):
    print(f"Track {track_idx} -> Detection {det_idx} (IoU: {similarity_matrix[track_idx, det_idx]:.3f})")
# Out:
# Assignations optimales:
# Track 0 -> Detection 7 (IoU: 0.826)
# Track 1 -> Detection 1 (IoU: 0.930)
# Track 2 -> Detection 6 (IoU: 0.921)
# Track 3 -> Detection 1305 (IoU: 0.791)
# Track 5 -> Detection 378 (IoU: 0.303)
# Track 7 -> Detection 13 (IoU: 0.914)
# Track 8 -> Detection 1558 (IoU: 0.603)
# Track 9 -> Detection 2 (IoU: 0.833)
# Track 10 -> Detection 591 (IoU: 0.952)
# Track 13 -> Detection 37 (IoU: 0.945)
# Track 15 -> Detection 20 (IoU: 0.843)
# Track 16 -> Detection 1023 (IoU: 0.922)
# Track 17 -> Detection 658 (IoU: 0.941)
# Track 18 -> Detection 9 (IoU: 0.816)
# Track 19 -> Detection 3 (IoU: 0.903)
# Track 22 -> Detection 386 (IoU: 0.297)
# Track 25 -> Detection 27 (IoU: 0.847)
# Track 26 -> Detection 669 (IoU: 0.937)
# Track 29 -> Detection 17 (IoU: 0.819)
# Track 31 -> Detection 8 (IoU: 0.932)
# Track 32 -> Detection 23 (IoU: 0.947)
# Track 33 -> Detection 909 (IoU: 0.925)
# Track 34 -> Detection 34 (IoU: 0.835)
# Track 36 -> Detection 39 (IoU: 0.837)
# Track 38 -> Detection 1427 (IoU: 0.537)
# Track 39 -> Detection 22 (IoU: 0.953)
# Track 41 -> Detection 48 (IoU: 0.808)
# Track 42 -> Detection 650 (IoU: 0.915)
# Track 45 -> Detection 35 (IoU: 0.934)
# Track 46 -> Detection 51 (IoU: 0.926)
# Track 49 -> Detection 471 (IoU: 0.913)
# Track 51 -> Detection 42 (IoU: 0.963)
# Track 52 -> Detection 58 (IoU: 0.914)
# Track 53 -> Detection 28 (IoU: 0.831)
# Track 56 -> Detection 324 (IoU: 0.953)
# Track 57 -> Detection 49 (IoU: 0.967)
# Track 58 -> Detection 50 (IoU: 0.934)
# Track 59 -> Detection 354 (IoU: 0.113)
# Track 7457 -> Detection 3005 (IoU: 0.813)
# Track 7460 -> Detection 3611 (IoU: 0.533)
# Track 7461 -> Detection 3490 (IoU: 0.882)
# Track 7463 -> Detection 4466 (IoU: 0.738)
# Track 7465 -> Detection 4463 (IoU: 0.888)
# Track 7466 -> Detection 2680 (IoU: 0.700)
# Track 7468 -> Detection 3621 (IoU: 0.608)
# Track 7471 -> Detection 4476 (IoU: 0.931)
# Track 7472 -> Detection 4464 (IoU: 0.927)
# Track 7476 -> Detection 3906 (IoU: 0.358)
# Track 7479 -> Detection 2646 (IoU: 0.681)
# Track 7480 -> Detection 4473 (IoU: 0.946)
# Track 7483 -> Detection 4498 (IoU: 0.750)
# Track 7484 -> Detection 4479 (IoU: 0.786)
# Track 7486 -> Detection 4482 (IoU: 0.833)
# Track 7491 -> Detection 4461 (IoU: 0.873)
# Track 7492 -> Detection 4031 (IoU: 0.921)
# Track 7493 -> Detection 4375 (IoU: 0.940)
# Track 7497 -> Detection 4495 (IoU: 0.889)
# Track 7499 -> Detection 2198 (IoU: 0.873)
# Track 7500 -> Detection 4471 (IoU: 0.898)
# Track 7506 -> Detection 3453 (IoU: 0.916)
# Track 7507 -> Detection 1400 (IoU: 0.223)
# Track 7508 -> Detection 1935 (IoU: 0.892)
# Track 7509 -> Detection 1720 (IoU: 0.788)
# Track 7514 -> Detection 4493 (IoU: 0.949)
# Track 7515 -> Detection 1729 (IoU: 0.865)
# Track 7517 -> Detection 2292 (IoU: 0.919)
# Track 7518 -> Detection 3876 (IoU: 0.862)
# Track 7519 -> Detection 1728 (IoU: 0.884)
# Track 7520 -> Detection 3608 (IoU: 0.847)
# Track 7522 -> Detection 4409 (IoU: 0.909)
# Track 7523 -> Detection 4525 (IoU: 0.888)
# Track 7525 -> Detection 1961 (IoU: 0.901)
# Track 7526 -> Detection 4528 (IoU: 0.965)
# Track 7527 -> Detection 3600 (IoU: 0.854)
# Track 7529 -> Detection 4540 (IoU: 0.880)
# Track 7531 -> Detection 4533 (IoU: 0.889)
# Track 7532 -> Detection 4475 (IoU: 0.799)
# Track 7533 -> Detection 1975 (IoU: 0.917)
# Track 7534 -> Detection 4546 (IoU: 0.967)
# Track 7535 -> Detection 3594 (IoU: 0.748)
# Track 7538 -> Detection 4539 (IoU: 0.871)
# Track 7539 -> Detection 1678 (IoU: 0.826)
# Track 7540 -> Detection 4554 (IoU: 0.964)
# Track 7541 -> Detection 3801 (IoU: 0.935)
# Track 7544 -> Detection 26 (IoU: 0.890)
# Track 7547 -> Detection 4548 (IoU: 0.957)

# %%
MAX_FRAMES_PERDUES = 20  # Nombre maximum de frames où une trajectoire peut être perdue
SEUIL_IOU = 0.1
matches = []  # Paires (track_id, detection_id) associées
unmatched_tracks = []  # Trajectoires non associées
unmatched_detections = []  # Détections non associées

for track_idx, det_idx in zip(tracked_indices, detection_indices):
    if similarity_matrix[track_idx, det_idx] >= SEUIL_IOU:
        matches.append((track_idx, det_idx))
    else:
        unmatched_tracks.append(track_idx)
        unmatched_detections.append(det_idx)

# Ajouter les indices non utilisés aux listes non appariées
all_tracks = set(range(len(tracked_bboxes)))
all_detections = set(range(len(detection_bboxes)))

matched_tracks = set(match[0] for match in matches)
matched_detections = set(match[1] for match in matches)

unmatched_tracks.extend(list(all_tracks - matched_tracks))
unmatched_detections.extend(list(all_detections - matched_detections))

print("\nRésultats de l'association:")
print(f"Nombre d'associations: {len(matches)}")
print(f"Trajectoires non associées: {len(unmatched_tracks)}")
print(f"Détections non associées: {len(unmatched_detections)}")


print("\nMise à jour des trajectoires:")
for track_idx, det_idx in matches:
    print(f"Trajectoire {track_idx} mise à jour avec détection {det_idx}")
    

print("\nTrajectoires non associées à supprimer si dépassement du seuil:")
for track_idx in unmatched_tracks:
    print(f"Trajectoire {track_idx} non associée")


print("\nNouvelles trajectoires à créer:")
for det_idx in unmatched_detections:
    print(f"Nouvelle trajectoire pour détection {det_idx}")
# Out:
# Résultats de l'association:
# Nombre d'associations: 4470
# Trajectoires non associées: 3174
# Détections non associées: 184
#
# Mise à jour des trajectoires:
# Trajectoire 0 mise à jour avec détection 7
# Trajectoire 1 mise à jour avec détection 1
# Trajectoire 2 mise à jour avec détection 6
# Trajectoire 3 mise à jour avec détection 1305
# Trajectoire 5 mise à jour avec détection 378
# Trajectoire 7 mise à jour avec détection 13
# Trajectoire 8 mise à jour avec détection 1558
# Trajectoire 9 mise à jour avec détection 2
# Trajectoire 10 mise à jour avec détection 591
# Trajectoire 13 mise à jour avec détection 37
# Trajectoire 15 mise à jour avec détection 20
# Trajectoire 16 mise à jour avec détection 1023
# Trajectoire 17 mise à jour avec détection 658
# Trajectoire 18 mise à jour avec détection 9
# Trajectoire 19 mise à jour avec détection 3
# Trajectoire 22 mise à jour avec détection 386
# Trajectoire 25 mise à jour avec détection 27
# Trajectoire 26 mise à jour avec détection 669
# Trajectoire 29 mise à jour avec détection 17
# Trajectoire 31 mise à jour avec détection 8
# Trajectoire 32 mise à jour avec détection 23
# Trajectoire 33 mise à jour avec détection 909
# Trajectoire 34 mise à jour avec détection 34
# Trajectoire 36 mise à jour avec détection 39
# Trajectoire 38 mise à jour avec détection 1427
# Trajectoire 39 mise à jour avec détection 22
# Trajectoire 41 mise à jour avec détection 48
# Trajectoire 42 mise à jour avec détection 650
# Trajectoire 45 mise à jour avec détection 35
# Trajectoire 46 mise à jour avec détection 51
# Trajectoire 49 mise à jour avec détection 471
# Trajectoire 51 mise à jour avec détection 42
# Trajectoire 52 mise à jour avec détection 58
# Trajectoire 53 mise à jour avec détection 28
# Trajectoire 56 mise à jour avec détection 324
# Trajectoire 57 mise à jour avec détection 49
# Trajectoire 58 mise à jour avec détection 50
# Trajectoire 59 mise à jour avec détection 354
# Trajectoire 61 mise à jour avec détection 53
# Trajectoire 62 mise à jour avec détection 642
# Trajectoire 63 mise à jour avec détection 56
# Trajectoire 64 mise à jour avec détection 36
# Trajectoire 65 mise à jour avec détection 41
# Trajectoire 66 mise à jour avec détection 316
# Trajectoire 67 mise à jour avec détection 82
# Trajectoire 68 mise à jour avec détection 63
# Trajectoire 70 mise à jour avec détection 88
# Trajectoire 71 mise à jour avec détection 54
# Trajectoire 72 mise à jour avec détection 4376
# Trajectoire 73 mise à jour avec détection 67
# Trajectoire 74 mise à jour avec détection 77
# Trajectoire 75 mise à jour avec détection 85
# Trajectoire 76 mise à jour avec détection 93
# Trajectoire 78 mise à jour avec détection 104
# Trajectoire 80 mise à jour avec détection 64
# Trajectoire 82 mise à jour avec détection 934
# Trajectoire 83 mise à jour avec détection 172
# Trajectoire 84 mise à jour avec détection 65
# Trajectoire 85 mise à jour avec détection 965
# Trajectoire 87 mise à jour avec détection 81
# Trajectoire 88 mise à jour avec détection 3632
# Trajectoire 89 mise à jour avec détection 120
# Trajectoire 90 mise à jour avec détection 84
# Trajectoire 91 mise à jour avec détection 78
# Trajectoire 94 mise à jour avec détection 89
# Trajectoire 95 mise à jour avec détection 4357
# Trajectoire 96 mise à jour avec détection 99
# Trajectoire 97 mise à jour avec détection 107
# Trajectoire 98 mise à jour avec détection 90
# Trajectoire 100 mise à jour avec détection 47
# Trajectoire 101 mise à jour avec détection 114
# Trajectoire 102 mise à jour avec détection 100
# Trajectoire 103 mise à jour avec détection 96
# Trajectoire 104 mise à jour avec détection 136
# Trajectoire 105 mise à jour avec détection 117
# Trajectoire 106 mise à jour avec détection 122
# Trajectoire 108 mise à jour avec détection 118
# Trajectoire 109 mise à jour avec détection 179
# Trajectoire 110 mise à jour avec détection 95
# Trajectoire 111 mise à jour avec détection 130
# Trajectoire 112 mise à jour avec détection 123
# Trajectoire 113 mise à jour avec détection 3305
# Trajectoire 114 mise à jour avec détection 150
# Trajectoire 115 mise à jour avec détection 55
# Trajectoire 116 mise à jour avec détection 132
# Trajectoire 117 mise à jour avec détection 137
# Trajectoire 118 mise à jour avec détection 147
# Trajectoire 119 mise à jour avec détection 131
# Trajectoire 120 mise à jour avec détection 143
# Trajectoire 121 mise à jour avec détection 588
# Trajectoire 122 mise à jour avec détection 135
# Trajectoire 123 mise à jour avec détection 148
# Trajectoire 125 mise à jour avec détection 144
# Trajectoire 126 mise à jour avec détection 105
# Trajectoire 128 mise à jour avec détection 124
# Trajectoire 129 mise à jour avec détection 165
# Trajectoire 130 mise à jour avec détection 170
# Trajectoire 132 mise à jour avec détection 125
# Trajectoire 134 mise à jour avec détection 139
# Trajectoire 136 mise à jour avec détection 98
# Trajectoire 137 mise à jour avec détection 142
# Trajectoire 138 mise à jour avec détection 159
# Trajectoire 139 mise à jour avec détection 162
# Trajectoire 140 mise à jour avec détection 138
# Trajectoire 141 mise à jour avec détection 154
# Trajectoire 142 mise à jour avec détection 242
# Trajectoire 143 mise à jour avec détection 164
# Trajectoire 144 mise à jour avec détection 166
# Trajectoire 145 mise à jour avec détection 153
# Trajectoire 146 mise à jour avec détection 168
# Trajectoire 147 mise à jour avec détection 167
# Trajectoire 148 mise à jour avec détection 252
# Trajectoire 149 mise à jour avec détection 173
# Trajectoire 152 mise à jour avec détection 655
# Trajectoire 153 mise à jour avec détection 226
# Trajectoire 154 mise à jour avec détection 180
# Trajectoire 158 mise à jour avec détection 197
# Trajectoire 159 mise à jour avec détection 187
# Trajectoire 160 mise à jour avec détection 189
# Trajectoire 162 mise à jour avec détection 685
# Trajectoire 163 mise à jour avec détection 220
# Trajectoire 164 mise à jour avec détection 156
# Trajectoire 165 mise à jour avec détection 193
# Trajectoire 166 mise à jour avec détection 176
# Trajectoire 167 mise à jour avec détection 175
# Trajectoire 168 mise à jour avec détection 214
# Trajectoire 169 mise à jour avec détection 215
# Trajectoire 170 mise à jour avec détection 177
# Trajectoire 171 mise à jour avec détection 205
# Trajectoire 172 mise à jour avec détection 169
# Trajectoire 173 mise à jour avec détection 194
# Trajectoire 174 mise à jour avec détection 222
# Trajectoire 175 mise à jour avec détection 289
# Trajectoire 176 mise à jour avec détection 191
# Trajectoire 180 mise à jour avec détection 301
# Trajectoire 182 mise à jour avec détection 211
# Trajectoire 183 mise à jour avec détection 206
# Trajectoire 185 mise à jour avec détection 748
# Trajectoire 188 mise à jour avec détection 212
# Trajectoire 190 mise à jour avec détection 740
# Trajectoire 191 mise à jour avec détection 224
# Trajectoire 193 mise à jour avec détection 181
# Trajectoire 194 mise à jour avec détection 282
# Trajectoire 195 mise à jour avec détection 198
# Trajectoire 196 mise à jour avec détection 234
# Trajectoire 197 mise à jour avec détection 223
# Trajectoire 199 mise à jour avec détection 722
# Trajectoire 200 mise à jour avec détection 216
# Trajectoire 201 mise à jour avec détection 240
# Trajectoire 204 mise à jour avec détection 295
# Trajectoire 205 mise à jour avec détection 243
# Trajectoire 206 mise à jour avec détection 245
# Trajectoire 208 mise à jour avec détection 251
# Trajectoire 209 mise à jour avec détection 315
# Trajectoire 210 mise à jour avec détection 232
# Trajectoire 212 mise à jour avec détection 233
# Trajectoire 213 mise à jour avec détection 202
# Trajectoire 214 mise à jour avec détection 500
# Trajectoire 215 mise à jour avec détection 248
# Trajectoire 218 mise à jour avec détection 239
# Trajectoire 219 mise à jour avec détection 250
# Trajectoire 220 mise à jour avec détection 196
# Trajectoire 222 mise à jour avec détection 525
# Trajectoire 224 mise à jour avec détection 256
# Trajectoire 225 mise à jour avec détection 255
# Trajectoire 226 mise à jour avec détection 263
# Trajectoire 227 mise à jour avec détection 484
# Trajectoire 231 mise à jour avec détection 262
# Trajectoire 232 mise à jour avec détection 246
# Trajectoire 234 mise à jour avec détection 323
# Trajectoire 237 mise à jour avec détection 268
# Trajectoire 238 mise à jour avec détection 235
# Trajectoire 239 mise à jour avec détection 666
# Trajectoire 241 mise à jour avec détection 3610
# Trajectoire 242 mise à jour avec détection 361
# Trajectoire 244 mise à jour avec détection 275
# Trajectoire 245 mise à jour avec détection 219
# Trajectoire 246 mise à jour avec détection 539
# Trajectoire 248 mise à jour avec détection 558
# Trajectoire 249 mise à jour avec détection 271
# Trajectoire 251 mise à jour avec détection 267
# Trajectoire 252 mise à jour avec détection 280
# Trajectoire 253 mise à jour avec détection 207
# Trajectoire 256 mise à jour avec détection 372
# Trajectoire 257 mise à jour avec détection 353
# Trajectoire 258 mise à jour avec détection 363
# Trajectoire 259 mise à jour avec détection 286
# Trajectoire 260 mise à jour avec détection 287
# Trajectoire 261 mise à jour avec détection 274
# Trajectoire 262 mise à jour avec détection 350
# Trajectoire 263 mise à jour avec détection 566
# Trajectoire 265 mise à jour avec détection 285
# Trajectoire 267 mise à jour avec détection 293
# Trajectoire 268 mise à jour avec détection 288
# Trajectoire 269 mise à jour avec détection 342
# Trajectoire 270 mise à jour avec détection 86
# Trajectoire 272 mise à jour avec détection 292
# Trajectoire 274 mise à jour avec détection 294
# Trajectoire 275 mise à jour avec détection 589
# Trajectoire 278 mise à jour avec détection 273
# Trajectoire 279 mise à jour avec détection 299
# Trajectoire 280 mise à jour avec détection 306
# Trajectoire 283 mise à jour avec détection 24
# Trajectoire 284 mise à jour avec détection 312
# Trajectoire 288 mise à jour avec détection 3384
# Trajectoire 289 mise à jour avec détection 309
# Trajectoire 291 mise à jour avec détection 348
# Trajectoire 292 mise à jour avec détection 319
# Trajectoire 293 mise à jour avec détection 314
# Trajectoire 295 mise à jour avec détection 4144
# Trajectoire 297 mise à jour avec détection 326
# Trajectoire 298 mise à jour avec détection 332
# Trajectoire 299 mise à jour avec détection 327
# Trajectoire 300 mise à jour avec détection 328
# Trajectoire 303 mise à jour avec détection 318
# Trajectoire 304 mise à jour avec détection 331
# Trajectoire 305 mise à jour avec détection 357
# Trajectoire 308 mise à jour avec détection 4487
# Trajectoire 310 mise à jour avec détection 336
# Trajectoire 313 mise à jour avec détection 349
# Trajectoire 315 mise à jour avec détection 698
# Trajectoire 318 mise à jour avec détection 365
# Trajectoire 319 mise à jour avec détection 347
# Trajectoire 322 mise à jour avec détection 3542
# Trajectoire 323 mise à jour avec détection 351
# Trajectoire 326 mise à jour avec détection 339
# Trajectoire 329 mise à jour avec détection 3333
# Trajectoire 330 mise à jour avec détection 1099
# Trajectoire 332 mise à jour avec détection 374
# Trajectoire 333 mise à jour avec détection 355
# Trajectoire 336 mise à jour avec détection 3769
# Trajectoire 337 mise à jour avec détection 343
# Trajectoire 340 mise à jour avec détection 373
# Trajectoire 343 mise à jour avec détection 366
# Trajectoire 345 mise à jour avec détection 3512
# Trajectoire 346 mise à jour avec détection 381
# Trajectoire 347 mise à jour avec détection 382
# Trajectoire 352 mise à jour avec détection 389
# Trajectoire 354 mise à jour avec détection 376
# Trajectoire 355 mise à jour avec détection 359
# Trajectoire 358 mise à jour avec détection 397
# Trajectoire 359 mise à jour avec détection 390
# Trajectoire 360 mise à jour avec détection 392
# Trajectoire 364 mise à jour avec détection 415
# Trajectoire 365 mise à jour avec détection 375
# Trajectoire 366 mise à jour avec détection 407
# Trajectoire 367 mise à jour avec détection 398
# Trajectoire 368 mise à jour avec détection 467
# Trajectoire 372 mise à jour avec détection 383
# Trajectoire 374 mise à jour avec détection 523
# Trajectoire 376 mise à jour avec détection 422
# Trajectoire 377 mise à jour avec détection 1651
# Trajectoire 378 mise à jour avec détection 433
# Trajectoire 379 mise à jour avec détection 406
# Trajectoire 380 mise à jour avec détection 605
# Trajectoire 384 mise à jour avec détection 439
# Trajectoire 385 mise à jour avec détection 421
# Trajectoire 386 mise à jour avec détection 623
# Trajectoire 389 mise à jour avec détection 431
# Trajectoire 391 mise à jour avec détection 441
# Trajectoire 392 mise à jour avec détection 393
# Trajectoire 394 mise à jour avec détection 420
# Trajectoire 395 mise à jour avec détection 440
# Trajectoire 396 mise à jour avec détection 430
# Trajectoire 397 mise à jour avec détection 448
# Trajectoire 398 mise à jour avec détection 466
# Trajectoire 401 mise à jour avec détection 379
# Trajectoire 402 mise à jour avec détection 454
# Trajectoire 403 mise à jour avec détection 447
# Trajectoire 404 mise à jour avec détection 456
# Trajectoire 405 mise à jour avec détection 475
# Trajectoire 407 mise à jour avec détection 453
# Trajectoire 409 mise à jour avec détection 463
# Trajectoire 410 mise à jour avec détection 465
# Trajectoire 411 mise à jour avec détection 455
# Trajectoire 412 mise à jour avec détection 483
# Trajectoire 415 mise à jour avec détection 461
# Trajectoire 416 mise à jour avec détection 473
# Trajectoire 418 mise à jour avec détection 464
# Trajectoire 419 mise à jour avec détection 507
# Trajectoire 420 mise à jour avec détection 401
# Trajectoire 422 mise à jour avec détection 402
# Trajectoire 423 mise à jour avec détection 481
# Trajectoire 424 mise à jour avec détection 474
# Trajectoire 425 mise à jour avec détection 480
# Trajectoire 426 mise à jour avec détection 521
# Trajectoire 427 mise à jour avec détection 477
# Trajectoire 428 mise à jour avec détection 572
# Trajectoire 430 mise à jour avec détection 291
# Trajectoire 431 mise à jour avec détection 489
# Trajectoire 433 mise à jour avec détection 490
# Trajectoire 434 mise à jour avec détection 515
# Trajectoire 436 mise à jour avec détection 457
# Trajectoire 437 mise à jour avec détection 427
# Trajectoire 440 mise à jour avec détection 499
# Trajectoire 441 mise à jour avec détection 497
# Trajectoire 442 mise à jour avec détection 493
# Trajectoire 447 mise à jour avec détection 496
# Trajectoire 448 mise à jour avec détection 505
# Trajectoire 450 mise à jour avec détection 531
# Trajectoire 451 mise à jour avec détection 529
# Trajectoire 453 mise à jour avec détection 1951
# Trajectoire 455 mise à jour avec détection 369
# Trajectoire 458 mise à jour avec détection 459
# Trajectoire 459 mise à jour avec détection 537
# Trajectoire 460 mise à jour avec détection 506
# Trajectoire 461 mise à jour avec détection 418
# Trajectoire 464 mise à jour avec détection 253
# Trajectoire 467 mise à jour avec détection 452
# Trajectoire 469 mise à jour avec détection 358
# Trajectoire 472 mise à jour avec détection 1838
# Trajectoire 474 mise à jour avec détection 486
# Trajectoire 476 mise à jour avec détection 544
# Trajectoire 477 mise à jour avec détection 547
# Trajectoire 479 mise à jour avec détection 514
# Trajectoire 483 mise à jour avec détection 494
# Trajectoire 484 mise à jour avec détection 527
# Trajectoire 485 mise à jour avec détection 528
# Trajectoire 488 mise à jour avec détection 436
# Trajectoire 492 mise à jour avec détection 676
# Trajectoire 493 mise à jour avec détection 511
# Trajectoire 494 mise à jour avec détection 512
# Trajectoire 496 mise à jour avec détection 540
# Trajectoire 497 mise à jour avec détection 546
# Trajectoire 500 mise à jour avec détection 2255
# Trajectoire 501 mise à jour avec détection 502
# Trajectoire 505 mise à jour avec détection 360
# Trajectoire 510 mise à jour avec détection 590
# Trajectoire 511 mise à jour avec détection 3299
# Trajectoire 512 mise à jour avec détection 543
# Trajectoire 514 mise à jour avec détection 394
# Trajectoire 516 mise à jour avec détection 632
# Trajectoire 518 mise à jour avec détection 3217
# Trajectoire 520 mise à jour avec détection 317
# Trajectoire 521 mise à jour avec détection 3737
# Trajectoire 522 mise à jour avec détection 559
# Trajectoire 523 mise à jour avec détection 571
# Trajectoire 524 mise à jour avec détection 553
# Trajectoire 525 mise à jour avec détection 370
# Trajectoire 526 mise à jour avec détection 562
# Trajectoire 527 mise à jour avec détection 442
# Trajectoire 528 mise à jour avec détection 4245
# Trajectoire 530 mise à jour avec détection 469
# Trajectoire 531 mise à jour avec détection 3718
# Trajectoire 532 mise à jour avec détection 576
# Trajectoire 533 mise à jour avec détection 578
# Trajectoire 534 mise à jour avec détection 560
# Trajectoire 537 mise à jour avec détection 377
# Trajectoire 538 mise à jour avec détection 549
# Trajectoire 541 mise à jour avec détection 592
# Trajectoire 543 mise à jour avec détection 577
# Trajectoire 544 mise à jour avec détection 595
# Trajectoire 545 mise à jour avec détection 573
# Trajectoire 546 mise à jour avec détection 334
# Trajectoire 547 mise à jour avec détection 626
# Trajectoire 548 mise à jour avec détection 574
# Trajectoire 553 mise à jour avec détection 585
# Trajectoire 556 mise à jour avec détection 4545
# Trajectoire 558 mise à jour avec détection 723
# Trajectoire 560 mise à jour avec détection 594
# Trajectoire 561 mise à jour avec détection 593
# Trajectoire 562 mise à jour avec détection 579
# Trajectoire 563 mise à jour avec détection 101
# Trajectoire 565 mise à jour avec détection 764
# Trajectoire 568 mise à jour avec détection 611
# Trajectoire 569 mise à jour avec détection 602
# Trajectoire 571 mise à jour avec détection 581
# Trajectoire 573 mise à jour avec détection 1963
# Trajectoire 574 mise à jour avec détection 749
# Trajectoire 577 mise à jour avec détection 620
# Trajectoire 579 mise à jour avec détection 622
# Trajectoire 581 mise à jour avec détection 696
# Trajectoire 582 mise à jour avec détection 601
# Trajectoire 583 mise à jour avec détection 630
# Trajectoire 584 mise à jour avec détection 621
# Trajectoire 585 mise à jour avec détection 631
# Trajectoire 586 mise à jour avec détection 603
# Trajectoire 587 mise à jour avec détection 458
# Trajectoire 588 mise à jour avec détection 705
# Trajectoire 590 mise à jour avec détection 609
# Trajectoire 592 mise à jour avec détection 629
# Trajectoire 593 mise à jour avec détection 183
# Trajectoire 594 mise à jour avec détection 628
# Trajectoire 596 mise à jour avec détection 687
# Trajectoire 599 mise à jour avec détection 635
# Trajectoire 600 mise à jour avec détection 637
# Trajectoire 603 mise à jour avec détection 640
# Trajectoire 605 mise à jour avec détection 598
# Trajectoire 607 mise à jour avec détection 643
# Trajectoire 608 mise à jour avec détection 654
# Trajectoire 609 mise à jour avec détection 645
# Trajectoire 610 mise à jour avec détection 636
# Trajectoire 611 mise à jour avec détection 646
# Trajectoire 612 mise à jour avec détection 649
# Trajectoire 616 mise à jour avec détection 664
# Trajectoire 617 mise à jour avec détection 661
# Trajectoire 618 mise à jour avec détection 652
# Trajectoire 620 mise à jour avec détection 195
# Trajectoire 621 mise à jour avec détection 478
# Trajectoire 622 mise à jour avec détection 659
# Trajectoire 624 mise à jour avec détection 671
# Trajectoire 625 mise à jour avec détection 674
# Trajectoire 627 mise à jour avec détection 644
# Trajectoire 631 mise à jour avec détection 668
# Trajectoire 632 mise à jour avec détection 681
# Trajectoire 633 mise à jour avec détection 751
# Trajectoire 635 mise à jour avec détection 694
# Trajectoire 636 mise à jour avec détection 684
# Trajectoire 640 mise à jour avec détection 672
# Trajectoire 641 mise à jour avec détection 703
# Trajectoire 642 mise à jour avec détection 701
# Trajectoire 643 mise à jour avec détection 653
# Trajectoire 644 mise à jour avec détection 411
# Trajectoire 645 mise à jour avec détection 3727
# Trajectoire 646 mise à jour avec détection 699
# Trajectoire 647 mise à jour avec détection 692
# Trajectoire 648 mise à jour avec détection 683
# Trajectoire 649 mise à jour avec détection 737
# Trajectoire 650 mise à jour avec détection 673
# Trajectoire 651 mise à jour avec détection 310
# Trajectoire 652 mise à jour avec détection 3719
# Trajectoire 653 mise à jour avec détection 708
# Trajectoire 654 mise à jour avec détection 700
# Trajectoire 655 mise à jour avec détection 710
# Trajectoire 656 mise à jour avec détection 711
# Trajectoire 658 mise à jour avec détection 972
# Trajectoire 659 mise à jour avec détection 771
# Trajectoire 660 mise à jour avec détection 726
# Trajectoire 661 mise à jour avec détection 719
# Trajectoire 662 mise à jour avec détection 709
# Trajectoire 663 mise à jour avec détection 720
# Trajectoire 664 mise à jour avec détection 712
# Trajectoire 665 mise à jour avec détection 1007
# Trajectoire 666 mise à jour avec détection 763
# Trajectoire 669 mise à jour avec détection 729
# Trajectoire 670 mise à jour avec détection 762
# Trajectoire 671 mise à jour avec détection 746
# Trajectoire 673 mise à jour avec détection 209
# Trajectoire 675 mise à jour avec détection 811
# Trajectoire 676 mise à jour avec détection 747
# Trajectoire 677 mise à jour avec détection 753
# Trajectoire 679 mise à jour avec détection 765
# Trajectoire 682 mise à jour avec détection 769
# Trajectoire 683 mise à jour avec détection 752
# Trajectoire 685 mise à jour avec détection 743
# Trajectoire 689 mise à jour avec détection 754
# Trajectoire 690 mise à jour avec détection 758
# Trajectoire 691 mise à jour avec détection 759
# Trajectoire 692 mise à jour avec détection 768
# Trajectoire 693 mise à jour avec détection 760
# Trajectoire 695 mise à jour avec détection 615
# Trajectoire 696 mise à jour avec détection 766
# Trajectoire 697 mise à jour avec détection 805
# Trajectoire 701 mise à jour avec détection 3728
# Trajectoire 702 mise à jour avec détection 776
# Trajectoire 704 mise à jour avec détection 770
# Trajectoire 706 mise à jour avec détection 788
# Trajectoire 707 mise à jour avec détection 781
# Trajectoire 708 mise à jour avec détection 784
# Trajectoire 709 mise à jour avec détection 785
# Trajectoire 710 mise à jour avec détection 779
# Trajectoire 711 mise à jour avec détection 786
# Trajectoire 714 mise à jour avec détection 801
# Trajectoire 715 mise à jour avec détection 792
# Trajectoire 718 mise à jour avec détection 799
# Trajectoire 721 mise à jour avec détection 803
# Trajectoire 722 mise à jour avec détection 802
# Trajectoire 723 mise à jour avec détection 804
# Trajectoire 725 mise à jour avec détection 807
# Trajectoire 726 mise à jour avec détection 806
# Trajectoire 728 mise à jour avec détection 3673
# Trajectoire 729 mise à jour avec détection 810
# Trajectoire 731 mise à jour avec détection 817
# Trajectoire 733 mise à jour avec détection 808
# Trajectoire 737 mise à jour avec détection 335
# Trajectoire 739 mise à jour avec détection 821
# Trajectoire 741 mise à jour avec détection 823
# Trajectoire 742 mise à jour avec détection 819
# Trajectoire 743 mise à jour avec détection 835
# Trajectoire 744 mise à jour avec détection 3592
# Trajectoire 745 mise à jour avec détection 832
# Trajectoire 748 mise à jour avec détection 824
# Trajectoire 749 mise à jour avec détection 825
# Trajectoire 750 mise à jour avec détection 3342
# Trajectoire 751 mise à jour avec détection 838
# Trajectoire 752 mise à jour avec détection 822
# Trajectoire 753 mise à jour avec détection 834
# Trajectoire 755 mise à jour avec détection 842
# Trajectoire 756 mise à jour avec détection 3481
# Trajectoire 761 mise à jour avec détection 836
# Trajectoire 762 mise à jour avec détection 3432
# Trajectoire 764 mise à jour avec détection 850
# Trajectoire 765 mise à jour avec détection 736
# Trajectoire 767 mise à jour avec détection 841
# Trajectoire 768 mise à jour avec détection 854
# Trajectoire 769 mise à jour avec détection 856
# Trajectoire 770 mise à jour avec détection 839
# Trajectoire 771 mise à jour avec détection 868
# Trajectoire 772 mise à jour avec détection 853
# Trajectoire 773 mise à jour avec détection 862
# Trajectoire 775 mise à jour avec détection 858
# Trajectoire 776 mise à jour avec détection 859
# Trajectoire 779 mise à jour avec détection 851
# Trajectoire 782 mise à jour avec détection 110
# Trajectoire 784 mise à jour avec détection 866
# Trajectoire 786 mise à jour avec détection 864
# Trajectoire 789 mise à jour avec détection 3685
# Trajectoire 791 mise à jour avec détection 857
# Trajectoire 792 mise à jour avec détection 874
# Trajectoire 793 mise à jour avec détection 873
# Trajectoire 795 mise à jour avec détection 871
# Trajectoire 796 mise à jour avec détection 872
# Trajectoire 797 mise à jour avec détection 878
# Trajectoire 798 mise à jour avec détection 869
# Trajectoire 800 mise à jour avec détection 4368
# Trajectoire 801 mise à jour avec détection 880
# Trajectoire 803 mise à jour avec détection 898
# Trajectoire 804 mise à jour avec détection 876
# Trajectoire 806 mise à jour avec détection 4286
# Trajectoire 807 mise à jour avec détection 885
# Trajectoire 808 mise à jour avec détection 877
# Trajectoire 809 mise à jour avec détection 886
# Trajectoire 810 mise à jour avec détection 888
# Trajectoire 811 mise à jour avec détection 3283
# Trajectoire 813 mise à jour avec détection 890
# Trajectoire 817 mise à jour avec détection 4438
# Trajectoire 820 mise à jour avec détection 891
# Trajectoire 822 mise à jour avec détection 4448
# Trajectoire 823 mise à jour avec détection 4325
# Trajectoire 824 mise à jour avec détection 900
# Trajectoire 826 mise à jour avec détection 907
# Trajectoire 827 mise à jour avec détection 903
# Trajectoire 828 mise à jour avec détection 4263
# Trajectoire 830 mise à jour avec détection 905
# Trajectoire 831 mise à jour avec détection 897
# Trajectoire 832 mise à jour avec détection 901
# Trajectoire 833 mise à jour avec détection 1241
# Trajectoire 834 mise à jour avec détection 3408
# Trajectoire 835 mise à jour avec détection 4290
# Trajectoire 838 mise à jour avec détection 887
# Trajectoire 839 mise à jour avec détection 908
# Trajectoire 840 mise à jour avec détection 3505
# Trajectoire 841 mise à jour avec détection 567
# Trajectoire 842 mise à jour avec détection 910
# Trajectoire 843 mise à jour avec détection 922
# Trajectoire 846 mise à jour avec détection 3047
# Trajectoire 848 mise à jour avec détection 915
# Trajectoire 849 mise à jour avec détection 912
# Trajectoire 850 mise à jour avec détection 913
# Trajectoire 851 mise à jour avec détection 917
# Trajectoire 852 mise à jour avec détection 4507
# Trajectoire 855 mise à jour avec détection 952
# Trajectoire 857 mise à jour avec détection 906
# Trajectoire 858 mise à jour avec détection 4320
# Trajectoire 859 mise à jour avec détection 920
# Trajectoire 865 mise à jour avec détection 4276
# Trajectoire 867 mise à jour avec détection 2100
# Trajectoire 868 mise à jour avec détection 921
# Trajectoire 870 mise à jour avec détection 923
# Trajectoire 871 mise à jour avec détection 924
# Trajectoire 872 mise à jour avec détection 4468
# Trajectoire 873 mise à jour avec détection 1016
# Trajectoire 874 mise à jour avec détection 929
# Trajectoire 876 mise à jour avec détection 945
# Trajectoire 877 mise à jour avec détection 932
# Trajectoire 878 mise à jour avec détection 1197
# Trajectoire 879 mise à jour avec détection 2131
# Trajectoire 880 mise à jour avec détection 935
# Trajectoire 882 mise à jour avec détection 937
# Trajectoire 883 mise à jour avec détection 938
# Trajectoire 884 mise à jour avec détection 2216
# Trajectoire 885 mise à jour avec détection 2217
# Trajectoire 886 mise à jour avec détection 942
# Trajectoire 888 mise à jour avec détection 944
# Trajectoire 890 mise à jour avec détection 634
# Trajectoire 891 mise à jour avec détection 1358
# Trajectoire 895 mise à jour avec détection 951
# Trajectoire 897 mise à jour avec détection 3084
# Trajectoire 898 mise à jour avec détection 1037
# Trajectoire 899 mise à jour avec détection 2256
# Trajectoire 900 mise à jour avec détection 958
# Trajectoire 901 mise à jour avec détection 970
# Trajectoire 905 mise à jour avec détection 2541
# Trajectoire 906 mise à jour avec détection 967
# Trajectoire 908 mise à jour avec détection 961
# Trajectoire 909 mise à jour avec détection 918
# Trajectoire 911 mise à jour avec détection 925
# Trajectoire 914 mise à jour avec détection 968
# Trajectoire 915 mise à jour avec détection 978
# Trajectoire 917 mise à jour avec détection 986
# Trajectoire 918 mise à jour avec détection 979
# Trajectoire 920 mise à jour avec détection 3078
# Trajectoire 921 mise à jour avec détection 987
# Trajectoire 922 mise à jour avec détection 994
# Trajectoire 923 mise à jour avec détection 1006
# Trajectoire 924 mise à jour avec détection 981
# Trajectoire 929 mise à jour avec détection 998
# Trajectoire 930 mise à jour avec détection 980
# Trajectoire 931 mise à jour avec détection 1005
# Trajectoire 932 mise à jour avec détection 1002
# Trajectoire 933 mise à jour avec détection 1022
# Trajectoire 934 mise à jour avec détection 990
# Trajectoire 935 mise à jour avec détection 988
# Trajectoire 936 mise à jour avec détection 1012
# Trajectoire 937 mise à jour avec détection 1018
# Trajectoire 938 mise à jour avec détection 1021
# Trajectoire 940 mise à jour avec détection 1011
# Trajectoire 941 mise à jour avec détection 1019
# Trajectoire 942 mise à jour avec détection 1025
# Trajectoire 943 mise à jour avec détection 989
# Trajectoire 944 mise à jour avec détection 1027
# Trajectoire 945 mise à jour avec détection 1029
# Trajectoire 947 mise à jour avec détection 4491
# Trajectoire 948 mise à jour avec détection 1032
# Trajectoire 950 mise à jour avec détection 1033
# Trajectoire 951 mise à jour avec détection 1035
# Trajectoire 952 mise à jour avec détection 1034
# Trajectoire 954 mise à jour avec détection 1039
# Trajectoire 955 mise à jour avec détection 1028
# Trajectoire 957 mise à jour avec détection 1043
# Trajectoire 959 mise à jour avec détection 1030
# Trajectoire 960 mise à jour avec détection 1047
# Trajectoire 963 mise à jour avec détection 1050
# Trajectoire 964 mise à jour avec détection 1049
# Trajectoire 966 mise à jour avec détection 1054
# Trajectoire 968 mise à jour avec détection 1057
# Trajectoire 969 mise à jour avec détection 1065
# Trajectoire 970 mise à jour avec détection 1062
# Trajectoire 971 mise à jour avec détection 955
# Trajectoire 972 mise à jour avec détection 1061
# Trajectoire 973 mise à jour avec détection 1064
# Trajectoire 974 mise à jour avec détection 1040
# Trajectoire 975 mise à jour avec détection 1072
# Trajectoire 977 mise à jour avec détection 1044
# Trajectoire 979 mise à jour avec détection 3161
# Trajectoire 980 mise à jour avec détection 1056
# Trajectoire 981 mise à jour avec détection 1071
# Trajectoire 982 mise à jour avec détection 1042
# Trajectoire 984 mise à jour avec détection 1069
# Trajectoire 985 mise à jour avec détection 1073
# Trajectoire 986 mise à jour avec détection 1063
# Trajectoire 987 mise à jour avec détection 1078
# Trajectoire 988 mise à jour avec détection 996
# Trajectoire 989 mise à jour avec détection 1085
# Trajectoire 990 mise à jour avec détection 1096
# Trajectoire 991 mise à jour avec détection 1080
# Trajectoire 992 mise à jour avec détection 1086
# Trajectoire 993 mise à jour avec détection 238
# Trajectoire 995 mise à jour avec détection 1082
# Trajectoire 997 mise à jour avec détection 1771
# Trajectoire 998 mise à jour avec détection 1087
# Trajectoire 999 mise à jour avec détection 1094
# Trajectoire 1000 mise à jour avec détection 1091
# Trajectoire 1002 mise à jour avec détection 1093
# Trajectoire 1004 mise à jour avec détection 1102
# Trajectoire 1005 mise à jour avec détection 1149
# Trajectoire 1006 mise à jour avec détection 1083
# Trajectoire 1009 mise à jour avec détection 1103
# Trajectoire 1010 mise à jour avec détection 1111
# Trajectoire 1013 mise à jour avec détection 1097
# Trajectoire 1014 mise à jour avec détection 1109
# Trajectoire 1015 mise à jour avec détection 1110
# Trajectoire 1017 mise à jour avec détection 1106
# Trajectoire 1018 mise à jour avec détection 1121
# Trajectoire 1020 mise à jour avec détection 1116
# Trajectoire 1021 mise à jour avec détection 1117
# Trajectoire 1022 mise à jour avec détection 1114
# Trajectoire 1023 mise à jour avec détection 1127
# Trajectoire 1025 mise à jour avec détection 2378
# Trajectoire 1026 mise à jour avec détection 3708
# Trajectoire 1028 mise à jour avec détection 1133
# Trajectoire 1029 mise à jour avec détection 1126
# Trajectoire 1030 mise à jour avec détection 1822
# Trajectoire 1031 mise à jour avec détection 1136
# Trajectoire 1032 mise à jour avec détection 1120
# Trajectoire 1033 mise à jour avec détection 3562
# Trajectoire 1034 mise à jour avec détection 1132
# Trajectoire 1036 mise à jour avec détection 1137
# Trajectoire 1037 mise à jour avec détection 1142
# Trajectoire 1039 mise à jour avec détection 1135
# Trajectoire 1040 mise à jour avec détection 725
# Trajectoire 1041 mise à jour avec détection 1148
# Trajectoire 1042 mise à jour avec détection 4044
# Trajectoire 1043 mise à jour avec détection 1143
# Trajectoire 1044 mise à jour avec détection 1144
# Trajectoire 1048 mise à jour avec détection 3999
# Trajectoire 1051 mise à jour avec détection 1151
# Trajectoire 1054 mise à jour avec détection 1161
# Trajectoire 1055 mise à jour avec détection 1156
# Trajectoire 1056 mise à jour avec détection 1160
# Trajectoire 1057 mise à jour avec détection 1166
# Trajectoire 1060 mise à jour avec détection 1169
# Trajectoire 1061 mise à jour avec détection 429
# Trajectoire 1062 mise à jour avec détection 1164
# Trajectoire 1066 mise à jour avec détection 1176
# Trajectoire 1067 mise à jour avec détection 1178
# Trajectoire 1068 mise à jour avec détection 4089
# Trajectoire 1069 mise à jour avec détection 1182
# Trajectoire 1070 mise à jour avec détection 1184
# Trajectoire 1071 mise à jour avec détection 1177
# Trajectoire 1072 mise à jour avec détection 1175
# Trajectoire 1073 mise à jour avec détection 1186
# Trajectoire 1074 mise à jour avec détection 1191
# Trajectoire 1075 mise à jour avec détection 1200
# Trajectoire 1076 mise à jour avec détection 1185
# Trajectoire 1077 mise à jour avec détection 1195
# Trajectoire 1078 mise à jour avec détection 1193
# Trajectoire 1079 mise à jour avec détection 1199
# Trajectoire 1080 mise à jour avec détection 1194
# Trajectoire 1083 mise à jour avec détection 1201
# Trajectoire 1084 mise à jour avec détection 1204
# Trajectoire 1085 mise à jour avec détection 616
# Trajectoire 1086 mise à jour avec détection 1207
# Trajectoire 1087 mise à jour avec détection 3329
# Trajectoire 1088 mise à jour avec détection 1203
# Trajectoire 1089 mise à jour avec détection 1202
# Trajectoire 1091 mise à jour avec détection 1229
# Trajectoire 1092 mise à jour avec détection 1215
# Trajectoire 1093 mise à jour avec détection 4183
# Trajectoire 1094 mise à jour avec détection 1210
# Trajectoire 1095 mise à jour avec détection 1211
# Trajectoire 1096 mise à jour avec détection 1212
# Trajectoire 1097 mise à jour avec détection 1208
# Trajectoire 1098 mise à jour avec détection 1223
# Trajectoire 1099 mise à jour avec détection 1227
# Trajectoire 1100 mise à jour avec détection 1629
# Trajectoire 1101 mise à jour avec détection 1225
# Trajectoire 1102 mise à jour avec détection 2301
# Trajectoire 1103 mise à jour avec détection 1217
# Trajectoire 1106 mise à jour avec détection 1234
# Trajectoire 1107 mise à jour avec détection 2320
# Trajectoire 1108 mise à jour avec détection 1235
# Trajectoire 1109 mise à jour avec détection 1242
# Trajectoire 1110 mise à jour avec détection 1246
# Trajectoire 1111 mise à jour avec détection 1245
# Trajectoire 1112 mise à jour avec détection 1218
# Trajectoire 1113 mise à jour avec détection 1233
# Trajectoire 1115 mise à jour avec détection 1250
# Trajectoire 1117 mise à jour avec détection 1251
# Trajectoire 1118 mise à jour avec détection 1243
# Trajectoire 1119 mise à jour avec détection 1256
# Trajectoire 1121 mise à jour avec détection 1292
# Trajectoire 1122 mise à jour avec détection 1247
# Trajectoire 1123 mise à jour avec détection 1244
# Trajectoire 1124 mise à jour avec détection 1261
# Trajectoire 1126 mise à jour avec détection 1264
# Trajectoire 1127 mise à jour avec détection 1248
# Trajectoire 1128 mise à jour avec détection 1263
# Trajectoire 1129 mise à jour avec détection 1260
# Trajectoire 1130 mise à jour avec détection 1331
# Trajectoire 1131 mise à jour avec détection 1269
# Trajectoire 1132 mise à jour avec détection 1271
# Trajectoire 1133 mise à jour avec détection 1272
# Trajectoire 1134 mise à jour avec détection 1270
# Trajectoire 1135 mise à jour avec détection 1275
# Trajectoire 1136 mise à jour avec détection 1533
# Trajectoire 1141 mise à jour avec détection 1311
# Trajectoire 1142 mise à jour avec détection 1262
# Trajectoire 1143 mise à jour avec détection 1285
# Trajectoire 1144 mise à jour avec détection 1287
# Trajectoire 1145 mise à jour avec détection 1280
# Trajectoire 1146 mise à jour avec détection 1288
# Trajectoire 1148 mise à jour avec détection 1347
# Trajectoire 1149 mise à jour avec détection 1279
# Trajectoire 1150 mise à jour avec détection 1338
# Trajectoire 1151 mise à jour avec détection 1297
# Trajectoire 1152 mise à jour avec détection 1299
# Trajectoire 1154 mise à jour avec détection 1281
# Trajectoire 1155 mise à jour avec détection 4454
# Trajectoire 1156 mise à jour avec détection 1289
# Trajectoire 1157 mise à jour avec détection 1306
# Trajectoire 1158 mise à jour avec détection 1290
# Trajectoire 1159 mise à jour avec détection 1228
# Trajectoire 1160 mise à jour avec détection 1307
# Trajectoire 1161 mise à jour avec détection 1300
# Trajectoire 1162 mise à jour avec détection 1409
# Trajectoire 1163 mise à jour avec détection 4536
# Trajectoire 1164 mise à jour avec détection 129
# Trajectoire 1165 mise à jour avec détection 1315
# Trajectoire 1166 mise à jour avec détection 1308
# Trajectoire 1167 mise à jour avec détection 2370
# Trajectoire 1168 mise à jour avec détection 1301
# Trajectoire 1169 mise à jour avec détection 1321
# Trajectoire 1170 mise à jour avec détection 941
# Trajectoire 1171 mise à jour avec détection 1328
# Trajectoire 1173 mise à jour avec détection 1323
# Trajectoire 1175 mise à jour avec détection 1320
# Trajectoire 1177 mise à jour avec détection 2359
# Trajectoire 1178 mise à jour avec détection 1294
# Trajectoire 1179 mise à jour avec détection 1332
# Trajectoire 1180 mise à jour avec détection 4067
# Trajectoire 1182 mise à jour avec détection 1325
# Trajectoire 1183 mise à jour avec détection 1317
# Trajectoire 1184 mise à jour avec détection 1576
# Trajectoire 1186 mise à jour avec détection 1316
# Trajectoire 1187 mise à jour avec détection 1344
# Trajectoire 1189 mise à jour avec détection 1336
# Trajectoire 1190 mise à jour avec détection 1346
# Trajectoire 1191 mise à jour avec détection 1437
# Trajectoire 1192 mise à jour avec détection 1339
# Trajectoire 1193 mise à jour avec détection 1352
# Trajectoire 1194 mise à jour avec détection 2102
# Trajectoire 1195 mise à jour avec détection 1342
# Trajectoire 1196 mise à jour avec détection 1345
# Trajectoire 1197 mise à jour avec détection 1335
# Trajectoire 1198 mise à jour avec détection 1396
# Trajectoire 1199 mise à jour avec détection 1357
# Trajectoire 1200 mise à jour avec détection 1360
# Trajectoire 1201 mise à jour avec détection 1359
# Trajectoire 1204 mise à jour avec détection 1362
# Trajectoire 1205 mise à jour avec détection 1361
# Trajectoire 1206 mise à jour avec détection 1616
# Trajectoire 1207 mise à jour avec détection 1370
# Trajectoire 1208 mise à jour avec détection 1369
# Trajectoire 1209 mise à jour avec détection 1363
# Trajectoire 1210 mise à jour avec détection 1364
# Trajectoire 1211 mise à jour avec détection 1371
# Trajectoire 1212 mise à jour avec détection 1597
# Trajectoire 1213 mise à jour avec détection 2113
# Trajectoire 1214 mise à jour avec détection 1530
# Trajectoire 1215 mise à jour avec détection 1380
# Trajectoire 1217 mise à jour avec détection 1376
# Trajectoire 1218 mise à jour avec détection 1377
# Trajectoire 1219 mise à jour avec détection 1578
# Trajectoire 1220 mise à jour avec détection 1373
# Trajectoire 1222 mise à jour avec détection 1626
# Trajectoire 1223 mise à jour avec détection 1319
# Trajectoire 1224 mise à jour avec détection 2602
# Trajectoire 1226 mise à jour avec détection 1402
# Trajectoire 1228 mise à jour avec détection 1397
# Trajectoire 1229 mise à jour avec détection 1389
# Trajectoire 1230 mise à jour avec détection 1392
# Trajectoire 1231 mise à jour avec détection 1638
# Trajectoire 1232 mise à jour avec détection 3878
# Trajectoire 1233 mise à jour avec détection 1384
# Trajectoire 1234 mise à jour avec détection 1412
# Trajectoire 1235 mise à jour avec détection 1393
# Trajectoire 1236 mise à jour avec détection 1406
# Trajectoire 1237 mise à jour avec détection 1416
# Trajectoire 1239 mise à jour avec détection 1407
# Trajectoire 1241 mise à jour avec détection 1415
# Trajectoire 1242 mise à jour avec détection 1413
# Trajectoire 1244 mise à jour avec détection 1424
# Trajectoire 1246 mise à jour avec détection 1419
# Trajectoire 1249 mise à jour avec détection 1421
# Trajectoire 1250 mise à jour avec détection 3988
# Trajectoire 1251 mise à jour avec détection 1422
# Trajectoire 1252 mise à jour avec détection 1434
# Trajectoire 1253 mise à jour avec détection 1423
# Trajectoire 1254 mise à jour avec détection 1273
# Trajectoire 1256 mise à jour avec détection 1439
# Trajectoire 1257 mise à jour avec détection 1418
# Trajectoire 1258 mise à jour avec détection 2484
# Trajectoire 1259 mise à jour avec détection 1431
# Trajectoire 1261 mise à jour avec détection 1441
# Trajectoire 1262 mise à jour avec détection 1405
# Trajectoire 1263 mise à jour avec détection 2399
# Trajectoire 1264 mise à jour avec détection 1428
# Trajectoire 1265 mise à jour avec détection 2504
# Trajectoire 1268 mise à jour avec détection 1442
# Trajectoire 1269 mise à jour avec détection 1440
# Trajectoire 1270 mise à jour avec détection 1476
# Trajectoire 1272 mise à jour avec détection 2514
# Trajectoire 1273 mise à jour avec détection 1443
# Trajectoire 1274 mise à jour avec détection 1447
# Trajectoire 1275 mise à jour avec détection 1444
# Trajectoire 1276 mise à jour avec détection 1449
# Trajectoire 1277 mise à jour avec détection 1450
# Trajectoire 1278 mise à jour avec détection 2712
# Trajectoire 1279 mise à jour avec détection 1451
# Trajectoire 1280 mise à jour avec détection 2532
# Trajectoire 1281 mise à jour avec détection 1455
# Trajectoire 1284 mise à jour avec détection 1457
# Trajectoire 1285 mise à jour avec détection 1458
# Trajectoire 1288 mise à jour avec détection 1485
# Trajectoire 1289 mise à jour avec détection 1461
# Trajectoire 1291 mise à jour avec détection 3928
# Trajectoire 1292 mise à jour avec détection 1516
# Trajectoire 1294 mise à jour avec détection 1459
# Trajectoire 1295 mise à jour avec détection 2418
# Trajectoire 1296 mise à jour avec détection 4311
# Trajectoire 1297 mise à jour avec détection 2523
# Trajectoire 1298 mise à jour avec détection 1481
# Trajectoire 1299 mise à jour avec détection 1474
# Trajectoire 1301 mise à jour avec détection 1486
# Trajectoire 1302 mise à jour avec détection 1468
# Trajectoire 1303 mise à jour avec détection 1656
# Trajectoire 1304 mise à jour avec détection 4226
# Trajectoire 1305 mise à jour avec détection 1463
# Trajectoire 1306 mise à jour avec détection 1483
# Trajectoire 1307 mise à jour avec détection 1471
# Trajectoire 1308 mise à jour avec détection 1479
# Trajectoire 1310 mise à jour avec détection 1493
# Trajectoire 1311 mise à jour avec détection 4233
# Trajectoire 1312 mise à jour avec détection 1482
# Trajectoire 1313 mise à jour avec détection 1487
# Trajectoire 1314 mise à jour avec détection 1489
# Trajectoire 1317 mise à jour avec détection 1496
# Trajectoire 1318 mise à jour avec détection 1497
# Trajectoire 1320 mise à jour avec détection 1460
# Trajectoire 1321 mise à jour avec détection 1502
# Trajectoire 1322 mise à jour avec détection 1512
# Trajectoire 1325 mise à jour avec détection 1374
# Trajectoire 1326 mise à jour avec détection 1505
# Trajectoire 1327 mise à jour avec détection 1507
# Trajectoire 1328 mise à jour avec détection 1490
# Trajectoire 1329 mise à jour avec détection 1509
# Trajectoire 1333 mise à jour avec détection 1495
# Trajectoire 1334 mise à jour avec détection 1503
# Trajectoire 1335 mise à jour avec détection 1504
# Trajectoire 1338 mise à jour avec détection 1480
# Trajectoire 1339 mise à jour avec détection 1515
# Trajectoire 1340 mise à jour avec détection 1518
# Trajectoire 1341 mise à jour avec détection 1506
# Trajectoire 1342 mise à jour avec détection 1681
# Trajectoire 1343 mise à jour avec détection 2330
# Trajectoire 1346 mise à jour avec détection 1525
# Trajectoire 1347 mise à jour avec détection 1517
# Trajectoire 1349 mise à jour avec détection 2609
# Trajectoire 1350 mise à jour avec détection 538
# Trajectoire 1351 mise à jour avec détection 1521
# Trajectoire 1352 mise à jour avec détection 1527
# Trajectoire 1354 mise à jour avec détection 1196
# Trajectoire 1355 mise à jour avec détection 1536
# Trajectoire 1356 mise à jour avec détection 1523
# Trajectoire 1357 mise à jour avec détection 1009
# Trajectoire 1358 mise à jour avec détection 1539
# Trajectoire 1359 mise à jour avec détection 1514
# Trajectoire 1361 mise à jour avec détection 1556
# Trajectoire 1363 mise à jour avec détection 1567
# Trajectoire 1364 mise à jour avec détection 1543
# Trajectoire 1365 mise à jour avec détection 1534
# Trajectoire 1366 mise à jour avec détection 1535
# Trajectoire 1367 mise à jour avec détection 1554
# Trajectoire 1368 mise à jour avec détection 1555
# Trajectoire 1369 mise à jour avec détection 1532
# Trajectoire 1370 mise à jour avec détection 1753
# Trajectoire 1371 mise à jour avec détection 1628
# Trajectoire 1372 mise à jour avec détection 1551
# Trajectoire 1373 mise à jour avec détection 1560
# Trajectoire 1374 mise à jour avec détection 1537
# Trajectoire 1375 mise à jour avec détection 1546
# Trajectoire 1376 mise à jour avec détection 1974
# Trajectoire 1378 mise à jour avec détection 1586
# Trajectoire 1379 mise à jour avec détection 4053
# Trajectoire 1380 mise à jour avec détection 1559
# Trajectoire 1382 mise à jour avec détection 1571
# Trajectoire 1383 mise à jour avec détection 1572
# Trajectoire 1384 mise à jour avec détection 1566
# Trajectoire 1385 mise à jour avec détection 1547
# Trajectoire 1386 mise à jour avec détection 1698
# Trajectoire 1388 mise à jour avec détection 1569
# Trajectoire 1390 mise à jour avec détection 1570
# Trajectoire 1392 mise à jour avec détection 2506
# Trajectoire 1396 mise à jour avec détection 1579
# Trajectoire 1397 mise à jour avec détection 1580
# Trajectoire 1398 mise à jour avec détection 1581
# Trajectoire 1399 mise à jour avec détection 1577
# Trajectoire 1400 mise à jour avec détection 1584
# Trajectoire 1401 mise à jour avec détection 1582
# Trajectoire 1402 mise à jour avec détection 1573
# Trajectoire 1403 mise à jour avec détection 1708
# Trajectoire 1404 mise à jour avec détection 1590
# Trajectoire 1406 mise à jour avec détection 1595
# Trajectoire 1407 mise à jour avec détection 1574
# Trajectoire 1410 mise à jour avec détection 1592
# Trajectoire 1411 mise à jour avec détection 1722
# Trajectoire 1412 mise à jour avec détection 1596
# Trajectoire 1413 mise à jour avec détection 1600
# Trajectoire 1414 mise à jour avec détection 1605
# Trajectoire 1415 mise à jour avec détection 1583
# Trajectoire 1416 mise à jour avec détection 1602
# Trajectoire 1417 mise à jour avec détection 1601
# Trajectoire 1418 mise à jour avec détection 1589
# Trajectoire 1421 mise à jour avec détection 2435
# Trajectoire 1422 mise à jour avec détection 1610
# Trajectoire 1423 mise à jour avec détection 1615
# Trajectoire 1424 mise à jour avec détection 1623
# Trajectoire 1425 mise à jour avec détection 1603
# Trajectoire 1426 mise à jour avec détection 1606
# Trajectoire 1427 mise à jour avec détection 1599
# Trajectoire 1429 mise à jour avec détection 1549
# Trajectoire 1430 mise à jour avec détection 1643
# Trajectoire 1431 mise à jour avec détection 1619
# Trajectoire 1432 mise à jour avec détection 1609
# Trajectoire 1433 mise à jour avec détection 4324
# Trajectoire 1434 mise à jour avec détection 1624
# Trajectoire 1435 mise à jour avec détection 1613
# Trajectoire 1436 mise à jour avec détection 1625
# Trajectoire 1437 mise à jour avec détection 1621
# Trajectoire 1438 mise à jour avec détection 3266
# Trajectoire 1439 mise à jour avec détection 1575
# Trajectoire 1441 mise à jour avec détection 1635
# Trajectoire 1442 mise à jour avec détection 1631
# Trajectoire 1443 mise à jour avec détection 4264
# Trajectoire 1444 mise à jour avec détection 1636
# Trajectoire 1446 mise à jour avec détection 1634
# Trajectoire 1447 mise à jour avec détection 1608
# Trajectoire 1449 mise à jour avec détection 1630
# Trajectoire 1450 mise à jour avec détection 1642
# Trajectoire 1451 mise à jour avec détection 2729
# Trajectoire 1452 mise à jour avec détection 1633
# Trajectoire 1453 mise à jour avec détection 1641
# ...
# Trajectoire 6946 non associée
# Trajectoire 6947 non associée
# Trajectoire 6948 non associée
# Trajectoire 6951 non associée
# Trajectoire 6954 non associée
# Trajectoire 6955 non associée
# Trajectoire 6956 non associée
# Trajectoire 6957 non associée
# Trajectoire 6962 non associée
# Trajectoire 6964 non associée
# Trajectoire 6968 non associée
# Trajectoire 6969 non associée
# Trajectoire 6971 non associée
# Trajectoire 6972 non associée
# Trajectoire 6973 non associée
# Trajectoire 6974 non associée
# Trajectoire 6975 non associée
# Trajectoire 6976 non associée
# Trajectoire 6977 non associée
# Trajectoire 6979 non associée
# Trajectoire 6981 non associée
# Trajectoire 6985 non associée
# Trajectoire 6991 non associée
# Trajectoire 6992 non associée
# Trajectoire 6994 non associée
# Trajectoire 6996 non associée
# Trajectoire 6998 non associée
# Trajectoire 7001 non associée
# Trajectoire 7003 non associée
# Trajectoire 7005 non associée
# Trajectoire 7009 non associée
# Trajectoire 7010 non associée
# Trajectoire 7011 non associée
# Trajectoire 7012 non associée
# Trajectoire 7013 non associée
# Trajectoire 7014 non associée
# Trajectoire 7017 non associée
# Trajectoire 7018 non associée
# Trajectoire 7020 non associée
# Trajectoire 7021 non associée
# Trajectoire 7022 non associée
# Trajectoire 7023 non associée
# Trajectoire 7024 non associée
# Trajectoire 7025 non associée
# Trajectoire 7026 non associée
# Trajectoire 7027 non associée
# Trajectoire 7028 non associée
# Trajectoire 7029 non associée
# Trajectoire 7030 non associée
# Trajectoire 7031 non associée
# Trajectoire 7033 non associée
# Trajectoire 7034 non associée
# Trajectoire 7035 non associée
# Trajectoire 7036 non associée
# Trajectoire 7039 non associée
# Trajectoire 7041 non associée
# Trajectoire 7042 non associée
# Trajectoire 7043 non associée
# Trajectoire 7045 non associée
# Trajectoire 7047 non associée
# Trajectoire 7048 non associée
# Trajectoire 7051 non associée
# Trajectoire 7052 non associée
# Trajectoire 7057 non associée
# Trajectoire 7058 non associée
# Trajectoire 7059 non associée
# Trajectoire 7060 non associée
# Trajectoire 7065 non associée
# Trajectoire 7067 non associée
# Trajectoire 7068 non associée
# Trajectoire 7072 non associée
# Trajectoire 7075 non associée
# Trajectoire 7079 non associée
# Trajectoire 7082 non associée
# Trajectoire 7086 non associée
# Trajectoire 7089 non associée
# Trajectoire 7090 non associée
# Trajectoire 7093 non associée
# Trajectoire 7094 non associée
# Trajectoire 7095 non associée
# Trajectoire 7098 non associée
# Trajectoire 7101 non associée
# Trajectoire 7103 non associée
# Trajectoire 7355 non associée
# Trajectoire 7356 non associée
# Trajectoire 7357 non associée
# Trajectoire 7358 non associée
# Trajectoire 7362 non associée
# Trajectoire 7363 non associée
# Trajectoire 7368 non associée
# Trajectoire 7369 non associée
# Trajectoire 7372 non associée
# Trajectoire 7378 non associée
# Trajectoire 7380 non associée
# Trajectoire 7381 non associée
# Trajectoire 7382 non associée
# Trajectoire 7383 non associée
# Trajectoire 7385 non associée
# Trajectoire 7391 non associée
# Trajectoire 7394 non associée
# Trajectoire 7395 non associée
# Trajectoire 7399 non associée
# Trajectoire 7400 non associée
# Trajectoire 7402 non associée
# Trajectoire 7404 non associée
# Trajectoire 7408 non associée
# Trajectoire 7409 non associée
# Trajectoire 7410 non associée
# Trajectoire 7411 non associée
# Trajectoire 7413 non associée
# Trajectoire 7416 non associée
# Trajectoire 7417 non associée
# Trajectoire 7418 non associée
# Trajectoire 7421 non associée
# Trajectoire 7423 non associée
# Trajectoire 7424 non associée
# Trajectoire 7427 non associée
# Trajectoire 7428 non associée
# Trajectoire 7430 non associée
# Trajectoire 7431 non associée
# Trajectoire 7433 non associée
# Trajectoire 7436 non associée
# Trajectoire 7437 non associée
# Trajectoire 7439 non associée
# Trajectoire 7441 non associée
# Trajectoire 7443 non associée
# Trajectoire 7444 non associée
# Trajectoire 7445 non associée
# Trajectoire 7447 non associée
# Trajectoire 7451 non associée
# Trajectoire 7453 non associée
# Trajectoire 7454 non associée
# Trajectoire 7456 non associée
# Trajectoire 7458 non associée
# Trajectoire 7459 non associée
# Trajectoire 7462 non associée
# Trajectoire 7464 non associée
# Trajectoire 7467 non associée
# Trajectoire 7469 non associée
# Trajectoire 7470 non associée
# Trajectoire 7473 non associée
# Trajectoire 7474 non associée
# Trajectoire 7475 non associée
# Trajectoire 7477 non associée
# Trajectoire 7478 non associée
# Trajectoire 7481 non associée
# Trajectoire 7482 non associée
# Trajectoire 7485 non associée
# Trajectoire 7487 non associée
# Trajectoire 7488 non associée
# Trajectoire 7489 non associée
# Trajectoire 7490 non associée
# Trajectoire 7494 non associée
# Trajectoire 7495 non associée
# Trajectoire 7496 non associée
# Trajectoire 7498 non associée
# Trajectoire 7501 non associée
# Trajectoire 7502 non associée
# Trajectoire 7503 non associée
# Trajectoire 7504 non associée
# Trajectoire 7505 non associée
# Trajectoire 7510 non associée
# Trajectoire 7511 non associée
# Trajectoire 7512 non associée
# Trajectoire 7513 non associée
# Trajectoire 7516 non associée
# Trajectoire 7521 non associée
# Trajectoire 7524 non associée
# Trajectoire 7528 non associée
# Trajectoire 7530 non associée
# Trajectoire 7536 non associée
# Trajectoire 7537 non associée
# Trajectoire 7542 non associée
# Trajectoire 7543 non associée
# Trajectoire 7545 non associée
# Trajectoire 7546 non associée
# Trajectoire 7548 non associée
# Trajectoire 7549 non associée
# Trajectoire 7550 non associée
# Trajectoire 7551 non associée
#
# Nouvelles trajectoires à créer:
# Nouvelle trajectoire pour détection 380
# Nouvelle trajectoire pour détection 3998
# Nouvelle trajectoire pour détection 679
# Nouvelle trajectoire pour détection 388
# Nouvelle trajectoire pour détection 843
# Nouvelle trajectoire pour détection 697
# Nouvelle trajectoire pour détection 797
# Nouvelle trajectoire pour détection 3836
# Nouvelle trajectoire pour détection 4414
# Nouvelle trajectoire pour détection 3794
# Nouvelle trajectoire pour détection 1008
# Nouvelle trajectoire pour détection 443
# Nouvelle trajectoire pour détection 984
# Nouvelle trajectoire pour détection 974
# Nouvelle trajectoire pour détection 855
# Nouvelle trajectoire pour détection 460
# Nouvelle trajectoire pour détection 435
# Nouvelle trajectoire pour détection 3675
# Nouvelle trajectoire pour détection 660
# Nouvelle trajectoire pour détection 419
# Nouvelle trajectoire pour détection 470
# Nouvelle trajectoire pour détection 410
# Nouvelle trajectoire pour détection 3663
# Nouvelle trajectoire pour détection 151
# Nouvelle trajectoire pour détection 3853
# Nouvelle trajectoire pour détection 820
# Nouvelle trajectoire pour détection 993
# Nouvelle trajectoire pour détection 1710
# Nouvelle trajectoire pour détection 3676
# Nouvelle trajectoire pour détection 1723
# Nouvelle trajectoire pour détection 949
# Nouvelle trajectoire pour détection 4011
# Nouvelle trajectoire pour détection 4460
# Nouvelle trajectoire pour détection 3699
# Nouvelle trajectoire pour détection 303
# Nouvelle trajectoire pour détection 985
# Nouvelle trajectoire pour détection 4480
# Nouvelle trajectoire pour détection 670
# Nouvelle trajectoire pour détection 3826
# Nouvelle trajectoire pour détection 3816
# Nouvelle trajectoire pour détection 790
# Nouvelle trajectoire pour détection 3216
# Nouvelle trajectoire pour détection 3805
# Nouvelle trajectoire pour détection 715
# Nouvelle trajectoire pour détection 396
# Nouvelle trajectoire pour détection 861
# Nouvelle trajectoire pour détection 724
# Nouvelle trajectoire pour détection 4441
# Nouvelle trajectoire pour détection 4423
# Nouvelle trajectoire pour détection 4432
# Nouvelle trajectoire pour détection 4403
# Nouvelle trajectoire pour détection 1190
# Nouvelle trajectoire pour détection 849
# Nouvelle trajectoire pour détection 774
# Nouvelle trajectoire pour détection 1817
# Nouvelle trajectoire pour détection 798
# Nouvelle trajectoire pour détection 773
# Nouvelle trajectoire pour détection 404
# Nouvelle trajectoire pour détection 451
# Nouvelle trajectoire pour détection 837
# Nouvelle trajectoire pour détection 1267
# Nouvelle trajectoire pour détection 4022
# Nouvelle trajectoire pour détection 706
# Nouvelle trajectoire pour détection 1283
# Nouvelle trajectoire pour détection 783
# Nouvelle trajectoire pour détection 4450
# Nouvelle trajectoire pour détection 688
# Nouvelle trajectoire pour détection 1673
# Nouvelle trajectoire pour détection 1685
# Nouvelle trajectoire pour détection 1661
# Nouvelle trajectoire pour détection 3125
# Nouvelle trajectoire pour détection 733
# Nouvelle trajectoire pour détection 831
# Nouvelle trajectoire pour détection 4490
# Nouvelle trajectoire pour détection 809
# Nouvelle trajectoire pour détection 3688
# Nouvelle trajectoire pour détection 3700
# Nouvelle trajectoire pour détection 1046
# Nouvelle trajectoire pour détection 1697
# Nouvelle trajectoire pour détection 1295
# Nouvelle trajectoire pour détection 1568
# Nouvelle trajectoire pour détection 957
# Nouvelle trajectoire pour détection 928
# Nouvelle trajectoire pour détection 4501
# Nouvelle trajectoire pour détection 1017
# Nouvelle trajectoire pour détection 1001
# Nouvelle trajectoire pour détection 757
# Nouvelle trajectoire pour détection 3227
# Nouvelle trajectoire pour détection 4510
# Nouvelle trajectoire pour détection 742
# Nouvelle trajectoire pour détection 966
# Nouvelle trajectoire pour détection 976
# Nouvelle trajectoire pour détection 1046
# Nouvelle trajectoire pour détection 1568
# Nouvelle trajectoire pour détection 3125
# Nouvelle trajectoire pour détection 3663
# Nouvelle trajectoire pour détection 3675
# Nouvelle trajectoire pour détection 3676
# Nouvelle trajectoire pour détection 3688
# Nouvelle trajectoire pour détection 3699
# Nouvelle trajectoire pour détection 3700
# Nouvelle trajectoire pour détection 1661
# Nouvelle trajectoire pour détection 1673
# Nouvelle trajectoire pour détection 3216
# Nouvelle trajectoire pour détection 660
# Nouvelle trajectoire pour détection 1685
# Nouvelle trajectoire pour détection 151
# Nouvelle trajectoire pour détection 3227
# Nouvelle trajectoire pour détection 670
# Nouvelle trajectoire pour détection 1697
# Nouvelle trajectoire pour détection 1190
# Nouvelle trajectoire pour détection 679
# Nouvelle trajectoire pour détection 1710
# Nouvelle trajectoire pour détection 688
# Nouvelle trajectoire pour détection 697
# Nouvelle trajectoire pour détection 1723
# Nouvelle trajectoire pour détection 706
# Nouvelle trajectoire pour détection 715
# Nouvelle trajectoire pour détection 3794
# Nouvelle trajectoire pour détection 724
# Nouvelle trajectoire pour détection 733
# Nouvelle trajectoire pour détection 3805
# Nouvelle trajectoire pour détection 742
# Nouvelle trajectoire pour détection 3816
# Nouvelle trajectoire pour détection 3826
# Nouvelle trajectoire pour détection 1267
# Nouvelle trajectoire pour détection 757
# Nouvelle trajectoire pour détection 3836
# Nouvelle trajectoire pour détection 1283
# Nouvelle trajectoire pour détection 773
# Nouvelle trajectoire pour détection 774
# Nouvelle trajectoire pour détection 3853
# Nouvelle trajectoire pour détection 783
# Nouvelle trajectoire pour détection 1295
# Nouvelle trajectoire pour détection 790
# Nouvelle trajectoire pour détection 1817
# Nouvelle trajectoire pour détection 797
# Nouvelle trajectoire pour détection 798
# Nouvelle trajectoire pour détection 809
# Nouvelle trajectoire pour détection 303
# Nouvelle trajectoire pour détection 4403
# Nouvelle trajectoire pour détection 820
# Nouvelle trajectoire pour détection 4414
# Nouvelle trajectoire pour détection 831
# Nouvelle trajectoire pour détection 837
# Nouvelle trajectoire pour détection 4423
# Nouvelle trajectoire pour détection 843
# Nouvelle trajectoire pour détection 4432
# Nouvelle trajectoire pour détection 849
# Nouvelle trajectoire pour détection 855
# Nouvelle trajectoire pour détection 4441
# Nouvelle trajectoire pour détection 861
# Nouvelle trajectoire pour détection 4450
# Nouvelle trajectoire pour détection 4460
# Nouvelle trajectoire pour détection 380
# Nouvelle trajectoire pour détection 4480
# Nouvelle trajectoire pour détection 388
# Nouvelle trajectoire pour détection 4490
# Nouvelle trajectoire pour détection 396
# Nouvelle trajectoire pour détection 404
# Nouvelle trajectoire pour détection 4501
# Nouvelle trajectoire pour détection 410
# Nouvelle trajectoire pour détection 3998
# Nouvelle trajectoire pour détection 4510
# Nouvelle trajectoire pour détection 928
# Nouvelle trajectoire pour détection 419
# Nouvelle trajectoire pour détection 4011
# Nouvelle trajectoire pour détection 435
# Nouvelle trajectoire pour détection 949
# Nouvelle trajectoire pour détection 4022
# Nouvelle trajectoire pour détection 443
# Nouvelle trajectoire pour détection 957
# Nouvelle trajectoire pour détection 451
# Nouvelle trajectoire pour détection 966
# Nouvelle trajectoire pour détection 460
# Nouvelle trajectoire pour détection 974
# Nouvelle trajectoire pour détection 976
# Nouvelle trajectoire pour détection 470
# Nouvelle trajectoire pour détection 984
# Nouvelle trajectoire pour détection 985
# Nouvelle trajectoire pour détection 993
# Nouvelle trajectoire pour détection 1001
# Nouvelle trajectoire pour détection 1008
# Nouvelle trajectoire pour détection 1017

# %%
def visualise_tracking_results(video_path, tracked_objects, output_path):
    seq_info = {}
    with open(os.path.join(video_path, 'seqinfo.ini')) as f:
        for line in f:
            if '=' in line:
                key, value = line.strip().split('=')
                seq_info[key] = value

    # Configuration de la sortie vidéo
    frame_width = int(seq_info['imWidth'])
    frame_height = int(seq_info['imHeight'])
    fps = int(seq_info['frameRate'])
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    # Dictionnaire pour stocker les objets par frame
    objects_by_frame = {}
    
    # Réorganiser les objets par frame
    for track_id, track in tracked_objects.items():
        for frame_idx, bbox in track.items():
            if frame_idx not in objects_by_frame:
                objects_by_frame[frame_idx] = []
            objects_by_frame[frame_idx].append((track_id, bbox))


    # Pour chaque frame
    for frame_idx in range(1, int(seq_info['seqLength']) + 1):
        # Lecture de l'image
        img_path = os.path.join(video_path, 'img1', f'{frame_idx:06d}.jpg')
        frame = cv2.imread(img_path)
        
        if frame is None:
            continue

        # Dessiner tous les objets présents dans cette frame
        if frame_idx in objects_by_frame:
            for track_id, bbox in objects_by_frame[frame_idx]:
                x, y, w, h = map(int, bbox)
                
                # Dessin de la boîte englobante
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                
                # Affichage de l'ID
                cv2.putText(frame, f'ID: {track_id}', 
                          (x, y - 10), 
                          cv2.FONT_HERSHEY_SIMPLEX, 
                          0.9, 
                          (0, 255, 0), 
                          2)

        # Affichage de la frame
        cv2.imshow('Tracking Results', frame)
        
        # Sauvegarde de la frame dans la vidéo
        out.write(frame)
        
        # Attente de 30ms, sortie si 'q' est pressé
        if cv2.waitKey(30) & 0xFF == ord('q'):
            break

    # Nettoyage
    out.release()
    cv2.destroyAllWindows()

# Exemple d'utilisation:
video_path = 'ADL-Rundle-6'
output_path = 'tp2_result.mp4'
# Créer un dictionnaire pour stocker les objets suivis
tracked_objects = {}

# %%
class Track:
    def __init__(self, bbox, track_id):
        self.id = track_id
        self.bbox = bbox
        self.frames_perdus = 0
    
    def predict(self):
        # Sans Kalman, on garde simplement la dernière position connue
        return self.bbox
    
    def update(self, detection):
        # Mise à jour directe avec la nouvelle détection
        self.bbox = detection
        self.frames_perdus = 0

# %%
def tracker(detections_par_frame):
    tracks = []
    next_track_id = 1
    resultats = {}
    active_tracks = set()  # Pour suivre les IDs actifs
    
    for frame_id, detections in detections_par_frame.items():
        # 1. Prédiction pour toutes les trajectoires existantes
        for track in tracks:
            track.predict()
        
        # 2. Association avec les nouvelles détections
        if tracks and len(detections) > 0:
            similarity_matrix = np.zeros((len(tracks), len(detections)))
            for i, track in enumerate(tracks):
                for j, detection in enumerate(detections):
                    # Vérifier si les boîtes se chevauchent significativement
                    iou = calculate_iou(track.bbox, detection)
                    similarity_matrix[i,j] = iou
            
            # Augmenter le seuil IoU pour éviter les associations ambiguës
            SEUIL_IOU = 0.5  # Seuil plus strict
            similarity_matrix[similarity_matrix < SEUIL_IOU] = 0
            
            # Ne permettre qu'une seule association par détection
            cost_matrix = 1 - similarity_matrix
            track_indices, det_indices = linear_sum_assignment(cost_matrix)
            
            matches = []
            unmatched_tracks = list(range(len(tracks)))
            unmatched_detections = list(range(len(detections)))
            
            # Filtrer les associations en vérifiant les chevauchements
            for track_idx, det_idx in zip(track_indices, det_indices):
                if similarity_matrix[track_idx, det_idx] >= SEUIL_IOU:
                    # Vérifier s'il n'y a pas déjà une trajectoire active dans cette zone
                    overlap_found = False
                    for other_track in tracks:
                        if other_track.id != tracks[track_idx].id and \
                           other_track.frames_perdus == 0 and \
                           calculate_iou(other_track.bbox, detections[det_idx]) > 0.3:
                            overlap_found = True
                            break
                    
                    if not overlap_found:
                        matches.append((track_idx, det_idx))
                        if track_idx in unmatched_tracks:
                            unmatched_tracks.remove(track_idx)
                        if det_idx in unmatched_detections:
                            unmatched_detections.remove(det_idx)
        else:
            matches = []
            unmatched_tracks = list(range(len(tracks)))
            unmatched_detections = list(range(len(detections)))
        
        # 3. Mise à jour des trajectoires
        for track_idx, det_idx in matches:
            tracks[track_idx].update(detections[det_idx])
            resultats.setdefault(tracks[track_idx].id, {})[frame_id] = tracks[track_idx].bbox
            active_tracks.add(tracks[track_idx].id)
        
        # 4. Gestion des trajectoires non associées
        MAX_FRAMES_PERDUES = 15  # Réduire pour supprimer plus rapidement les trajectoires perdues
        for track_idx in unmatched_tracks:
            tracks[track_idx].frames_perdus += 1
            if tracks[track_idx].frames_perdus <= MAX_FRAMES_PERDUES:
                resultats.setdefault(tracks[track_idx].id, {})[frame_id] = tracks[track_idx].bbox
            else:
                active_tracks.discard(tracks[track_idx].id)
        
        # 5. Supprimer les trajectoires perdues
        tracks = [track for track in tracks if track.frames_perdus <= MAX_FRAMES_PERDUES]
        
        # 6. Créer de nouvelles trajectoires
        MIN_DISTANCE = 50  # Distance minimale entre les centres des boîtes
        for det_idx in unmatched_detections:
            # Vérifier si la détection est suffisamment éloignée des trajectoires existantes
            detection = detections[det_idx]
            det_center = (detection[0] + detection[2]/2, detection[1] + detection[3]/2)
            
            trop_proche = False
            for track in tracks:
                track_box = track.bbox
                track_center = (track_box[0] + track_box[2]/2, track_box[1] + track_box[3]/2)
                distance = np.sqrt((det_center[0] - track_center[0])**2 + 
                                 (det_center[1] - track_center[1])**2)
                if distance < MIN_DISTANCE:
                    trop_proche = True
                    break
            
            if not trop_proche:
                new_track = Track(detection, next_track_id)
                tracks.append(new_track)
                resultats.setdefault(next_track_id, {})[frame_id] = detection
                active_tracks.add(next_track_id)
                next_track_id += 1
    
    # 7. Filtrer les trajectoires trop courtes
    MIN_DETECTIONS = 5  # Augmenter pour avoir des trajectoires plus stables
    trajectoires_filtrees = {}
    for track_id, track_data in resultats.items():
        if len(track_data) >= MIN_DETECTIONS:
            trajectoires_filtrees[track_id] = track_data
    
    return trajectoires_filtrees

# %%
# Organiser les détections par frame
detections_yolov5s_par_frame = {
    frame: det_yolov5s[det_yolov5s['frame'] == frame].iloc[:, 2:6].values.tolist()
    for frame in det_yolov5s['frame'].unique()
}

# Lancer le tracking
resultats_tracking = tracker(detections_yolov5s_par_frame)

# Visualiser les résultats
visualise_tracking_results('ADL-Rundle-6', resultats_tracking, output_path)

# %%
def sauvegarder_resultats(tracked_objects, sequence_name):
    # Créer le fichier de sortie avec le même nom que la séquence
    output_file = f'{sequence_name}.txt'
    
    with open(output_file, 'w') as f:
        # Pour chaque objet suivi
        for track_id in tracked_objects:
            # Pour chaque frame où l'objet apparaît
            for frame_id in tracked_objects[track_id]:
                x, y, w, h = tracked_objects[track_id][frame_id]
                
                ligne = f"{frame_id},{track_id},{x},{y},{w},{h},1,-1,-1,-1\n"
                f.write(ligne)
                
    print(f"Résultats sauvegardés dans {output_file}")

# Sauvegarder les résultats pour la séquence ADL-Rundle-6
sauvegarder_resultats(resultats_tracking, 'ADL-Rundle-6')
# Out:
# Résultats sauvegardés dans ADL-Rundle-6.txt

# %% [markdown]
# # TP3

# %%
class KalmanFilter:
    def __init__(self, dt, u_x, u_y, std_acc, x_std_meas, y_std_meas):
        self.dt = dt
        
        self.u = np.array([[u_x], [u_y]])
        
        self.x = np.array([[0], [0], [0], [0]])
        
        self.A = np.array([
            [1, 0, self.dt, 0],
            [0, 1, 0, self.dt],
            [0, 0, 1, 0],
            [0, 0, 0, 1]
        ])
        
        self.B = np.array([
            [(self.dt ** 2) / 2, 0],
            [0, (self.dt ** 2) / 2],
            [self.dt, 0],
            [0, self.dt]
        ])
        
        self.H = np.array([
            [1, 0, 0, 0],
            [0, 1, 0, 0]
        ])
        
        self.Q = std_acc ** 2 * np.array([
            [(self.dt ** 4) / 4, 0, (self.dt ** 3) / 2, 0],
            [0, (self.dt ** 4) / 4, 0, (self.dt ** 3) / 2],
            [(self.dt ** 3) / 2, 0, self.dt ** 2, 0],
            [0, (self.dt ** 3) / 2, 0, self.dt ** 2]
        ])
        
        self.R = np.array([
            [x_std_meas ** 2, 0],
            [0, y_std_meas ** 2]
        ])
        
        self.P = np.eye(self.A.shape[1])

    def predict(self):
        self.x = np.dot(self.A, self.x) + np.dot(self.B, self.u)
        
        self.P = np.dot(np.dot(self.A, self.P), self.A.T) + self.Q
        
        return self.x[:2]

    def update(self, z):
        S = np.dot(np.dot(self.H, self.P), self.H.T) + self.R
        K = np.dot(np.dot(self.P, self.H.T), np.linalg.inv(S))

        y = z - np.dot(self.H, self.x)
        self.x = self.x + np.dot(K, y)

        I = np.eye(self.H.shape[1])
        self.P = np.dot((I - np.dot(K, self.H)), self.P)

        return self.x[:2]

# %%
class Track:
    def __init__(self, bbox, track_id):
        self.id = track_id
        self.bbox = bbox
        self.frames_perdus = 0
        
        # Initialisation du centre
        cx = bbox[0] + bbox[2]/2
        cy = bbox[1] + bbox[3]/2
        
        # Paramètres Kalman plus conservateurs
        self.kalman = KalmanFilter(
            dt=1.0,
            u_x=0,
            u_y=0,
            std_acc=0.1,  # Réduit pour moins extrapoler le mouvement
            x_std_meas=0.1,
            y_std_meas=0.1
        )
        
        self.kalman.x = np.array([[cx], [cy], [0], [0]])
        self.derniere_detection = bbox
        self.vitesse_max = 50  # Vitesse maximale autorisée en pixels par frame
        
    def predict(self):
        if self.frames_perdus > 5:  # Si perdu trop longtemps, on arrête de prédire
            return self.derniere_detection
            
        predicted_center = self.kalman.predict()
        cx, cy = predicted_center.flatten()
        
        # Calculer le déplacement
        ancien_cx = self.bbox[0] + self.bbox[2]/2
        ancien_cy = self.bbox[1] + self.bbox[3]/2
        deplacement = np.sqrt((cx - ancien_cx)**2 + (cy - ancien_cy)**2)
        
        # Si le déplacement est trop grand, on limite la prédiction
        if deplacement > self.vitesse_max:
            ratio = self.vitesse_max / deplacement
            cx = ancien_cx + (cx - ancien_cx) * ratio
            cy = ancien_cy + (cy - ancien_cy) * ratio
        
        # Conserver la taille de la boîte
        w, h = self.bbox[2], self.bbox[3]
        nouvelle_bbox = [cx - w/2, cy - h/2, w, h]
        
        # Vérifier que la boîte reste dans des limites raisonnables
        if self.est_bbox_valide(nouvelle_bbox):
            self.bbox = nouvelle_bbox
        
        return self.bbox
    
    def update(self, detection):
        self.derniere_detection = detection
        self.bbox = detection
        self.frames_perdus = 0
        
        # Mise à jour Kalman avec le centre de la détection
        cx = detection[0] + detection[2]/2
        cy = detection[1] + detection[3]/2
        measurement = np.array([[cx], [cy]])
        self.kalman.update(measurement)
    
    def est_bbox_valide(self, bbox):
        # Vérifier que la boîte est dans des limites raisonnables
        x, y, w, h = bbox
        return (0 <= x <= 1920 and
                0 <= y <= 1080 and
                10 <= w <= 1000 and
                10 <= h <= 1000)

# %%
def trackerKalman(detections_par_frame):
    tracks = []
    next_track_id = 1
    resultats = {}
    active_tracks = set()  # Pour suivre les IDs actifs
    
    for frame_id, detections in detections_par_frame.items():
        # 1. Prédiction pour toutes les trajectoires existantes
        for track in tracks:
            track.predict()
        
        # 2. Association avec les nouvelles détections
        if tracks and len(detections) > 0:
            similarity_matrix = np.zeros((len(tracks), len(detections)))
            for i, track in enumerate(tracks):
                for j, detection in enumerate(detections):
                    # Vérifier si les boîtes se chevauchent significativement
                    iou = calculate_iou(track.bbox, detection)
                    similarity_matrix[i,j] = iou
            
            # Augmenter le seuil IoU pour éviter les associations ambiguës
            SEUIL_IOU = 0.5  # Seuil plus strict
            similarity_matrix[similarity_matrix < SEUIL_IOU] = 0
            
            # Ne permettre qu'une seule association par détection
            cost_matrix = 1 - similarity_matrix
            track_indices, det_indices = linear_sum_assignment(cost_matrix)
            
            matches = []
            unmatched_tracks = list(range(len(tracks)))
            unmatched_detections = list(range(len(detections)))
            
            # Filtrer les associations en vérifiant les chevauchements
            for track_idx, det_idx in zip(track_indices, det_indices):
                if similarity_matrix[track_idx, det_idx] >= SEUIL_IOU:
                    # Vérifier s'il n'y a pas déjà une trajectoire active dans cette zone
                    overlap_found = False
                    for other_track in tracks:
                        if other_track.id != tracks[track_idx].id and \
                           other_track.frames_perdus == 0 and \
                           calculate_iou(other_track.bbox, detections[det_idx]) > 0.3:
                            overlap_found = True
                            break
                    
                    if not overlap_found:
                        matches.append((track_idx, det_idx))
                        if track_idx in unmatched_tracks:
                            unmatched_tracks.remove(track_idx)
                        if det_idx in unmatched_detections:
                            unmatched_detections.remove(det_idx)
        else:
            matches = []
            unmatched_tracks = list(range(len(tracks)))
            unmatched_detections = list(range(len(detections)))
        
        # 3. Mise à jour des trajectoires
        for track_idx, det_idx in matches:
            tracks[track_idx].update(detections[det_idx])
            resultats.setdefault(tracks[track_idx].id, {})[frame_id] = tracks[track_idx].bbox
            active_tracks.add(tracks[track_idx].id)
        
        # 4. Gestion des trajectoires non associées
        MAX_FRAMES_PERDUES = 15  # Réduire pour supprimer plus rapidement les trajectoires perdues
        for track_idx in unmatched_tracks:
            tracks[track_idx].frames_perdus += 1
            if tracks[track_idx].frames_perdus <= MAX_FRAMES_PERDUES:
                resultats.setdefault(tracks[track_idx].id, {})[frame_id] = tracks[track_idx].bbox
            else:
                active_tracks.discard(tracks[track_idx].id)
        
        # 5. Supprimer les trajectoires perdues
        tracks = [track for track in tracks if track.frames_perdus <= MAX_FRAMES_PERDUES]
        
        # 6. Créer de nouvelles trajectoires
        MIN_DISTANCE = 50  # Distance minimale entre les centres des boîtes
        for det_idx in unmatched_detections:
            # Vérifier si la détection est suffisamment éloignée des trajectoires existantes
            detection = detections[det_idx]
            det_center = (detection[0] + detection[2]/2, detection[1] + detection[3]/2)
            
            trop_proche = False
            for track in tracks:
                track_box = track.bbox
                track_center = (track_box[0] + track_box[2]/2, track_box[1] + track_box[3]/2)
                distance = np.sqrt((det_center[0] - track_center[0])**2 + 
                                 (det_center[1] - track_center[1])**2)
                if distance < MIN_DISTANCE:
                    trop_proche = True
                    break
            
            if not trop_proche:
                new_track = Track(detection, next_track_id)
                tracks.append(new_track)
                resultats.setdefault(next_track_id, {})[frame_id] = detection
                active_tracks.add(next_track_id)
                next_track_id += 1
    
    # 7. Filtrer les trajectoires trop courtes
    MIN_DETECTIONS = 10  # Augmenter pour avoir des trajectoires plus stables
    trajectoires_filtrees = {}
    for track_id, track_data in resultats.items():
        if len(track_data) >= MIN_DETECTIONS:
            trajectoires_filtrees[track_id] = track_data
    
    return trajectoires_filtrees

# %%
detections_yolov5s_par_frame = {
    frame: det_yolov5s[det_yolov5s['frame'] == frame].iloc[:, 2:6].values.tolist()
    for frame in det_yolov5s['frame'].unique()
}

resultats_tracking = trackerKalman(detections_yolov5s_par_frame)

visualise_tracking_results('ADL-Rundle-6', resultats_tracking, 'tp3_result.mp4')
